# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.ticker as mtick

# %%
df = pd.DataFrame(np.random.randint(0,11,size=(1000, 3)), columns=['Experience','Service','Arrival'])
df['Country Number'] = np.random.randint(1, 3, df.shape[0])

# %%
def country_name(x):
    if x['Country Number'] == 1:
        return 'United States'
    elif x['Country Number'] == 2:
        return 'Canada'
    elif x['Country Number'] == 3:
        return 'Mexico'
    elif x['Country Number'] == 4:
        return 'France'
    elif x['Country Number'] == 5:
        return 'Spain'
    else:
        pass

# %%
df['Country'] = df.apply(country_name, axis=1)

# %%
df
# Out:
#      Experience  Service  Arrival  Country Number        Country
# 0             0        4        9               1  United States
# 1             7        9       10               2         Canada
# 2             3        1        8               2         Canada
# 3             6        1        7               2         Canada
# 4            10        1        8               2         Canada
# ..          ...      ...      ...             ...            ...
# 995           1        4        3               2         Canada
# 996          10        2        0               2         Canada
# 997           4        1        4               1  United States
# 998           5        2        0               2         Canada
# 999           9        4        3               2         Canada
#
# [1000 rows x 5 columns]

# %%
def nps_bucket(x):
    if x > 8:
        bucket = 'promoter'
    elif x > 6:
        bucket = 'passive'
    elif x>= 0:
        bucket = 'detractor'
    else:
        bucket = 'no score'
    return bucket

# %%
#df_surveys_test.head()

melted_df = pd.melt(frame = df, id_vars = ['Country'], value_vars = ['Experience','Service','Arrival'],value_name='Score', var_name = 'Question' )

melted_df = melted_df.dropna()

melted_df['Score'] = pd.to_numeric(melted_df['Score'])

melted_df['nps_bucket'] = melted_df['Score'].apply(nps_bucket)

# %%
melted_df
# Out:
#             Country    Question  Score nps_bucket
# 0     United States  Experience      0  detractor
# 1            Canada  Experience      7    passive
# 2            Canada  Experience      3  detractor
# 3            Canada  Experience      6  detractor
# 4            Canada  Experience     10   promoter
# ...             ...         ...    ...        ...
# 2995         Canada     Arrival      3  detractor
# 2996         Canada     Arrival      0  detractor
# 2997  United States     Arrival      4  detractor
# 2998         Canada     Arrival      0  detractor
# 2999         Canada     Arrival      3  detractor
#
# [3000 rows x 4 columns]

# %%
#Calculate the overall Score by question
unpivoted = melted_df.groupby(['Country','Question'])['nps_bucket'].apply(lambda x: (x.str.contains('promoter').sum() - x.str.contains('detractor').sum()) / (x.str.contains('promoter').sum() + x.str.contains('passive').sum() + x.str.contains('detractor').sum())).reset_index()

pivoted = unpivoted.pivot(
    columns='Country',
    index='Question',
    values='nps_bucket')

#pivoted['Percent Change'] = pivoted['Used Messaging'] / pivoted['Did Not Use Messaging'] - 1

#pivoted.reset_index(inplace=True)

# %%
sns.set_style("whitegrid")
sns.set_context("poster", font_scale = 1)
f, ax = plt.subplots(figsize=(20,10))

sns.barplot(data = unpivoted, 
            x = 'Question', 
            y='nps_bucket', 
            hue='Country')
ax.set(xlabel='', ylabel='NPS Score')
ax.yaxis.set_major_formatter(mtick.PercentFormatter(xmax = 1))
ax.legend(loc=9, ncol=2)
#ax.set_ylim(.1,.2)
