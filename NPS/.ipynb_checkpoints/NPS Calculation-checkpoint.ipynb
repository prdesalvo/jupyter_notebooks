# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.ticker as mtick

# %%
df1 = pd.DataFrame(np.random.randint(9,11,size=(1000, 1)), columns=['How likely are you to reccomend the product?']) #promoters
df2 = pd.DataFrame(np.random.randint(7,9,size=(400, 1)), columns=['How likely are you to reccomend the product?']) #passives
df3 = pd.DataFrame(np.random.randint(0,7,size=(100, 1)), columns=['How likely are you to reccomend the product?']) #detractors

df = pd.concat([df1,df2,df3], ignore_index=True)

df['Country Number'] = np.random.randint(1, 6, df.shape[0])

# %%
df
# Out:
#       How likely are you to reccomend the product?  Country Number
# 0                                               10               5
# 1                                                9               1
# 2                                               10               4
# 3                                               10               1
# 4                                                9               4
# ...                                            ...             ...
# 1495                                             5               3
# 1496                                             5               4
# 1497                                             3               1
# 1498                                             0               1
# 1499                                             0               1
#
# [1500 rows x 2 columns]

# %%
def country_name(x):
    if x['Country Number'] == 1:
        return 'United States'
    elif x['Country Number'] == 2:
        return 'Canada'
    elif x['Country Number'] == 3:
        return 'Mexico'
    elif x['Country Number'] == 4:
        return 'France'
    elif x['Country Number'] == 5:
        return 'Spain'
    else:
        pass

# %%
df['Country'] = df.apply(country_name, axis=1)

# %%
df
# Out:
#       How likely are you to reccomend the product?  Country Number  \
# 0                                               10               5
# 1                                                9               1
# 2                                               10               4
# 3                                               10               1
# 4                                                9               4
# ...                                            ...             ...
# 1495                                             5               3
# 1496                                             5               4
# 1497                                             3               1
# 1498                                             0               1
# 1499                                             0               1
#
#             Country
# 0             Spain
# 1     United States
# 2            France
# 3     United States
# 4            France
# ...             ...
# 1495         Mexico
# 1496         France
# 1497  United States
# 1498  United States
# 1499  United States
#
# [1500 rows x 3 columns]

# %%
def nps_bucket(x):
    if x > 8:
        bucket = 'promoter'
    elif x > 6:
        bucket = 'passive'
    elif x>= 0:
        bucket = 'detractor'
    else:
        bucket = 'no score'
    return bucket

# %%
#df_surveys_test.head()

melted_df = pd.melt(frame = df, id_vars = ['Country'], value_vars = ['How likely are you to reccomend the product?'],value_name='Score', var_name = 'Question' )

melted_df = melted_df.dropna()

melted_df['Score'] = pd.to_numeric(melted_df['Score'])

melted_df['nps_bucket'] = melted_df['Score'].apply(nps_bucket)

# %%
melted_df
# Out:
#             Country                                      Question  Score  \
# 0             Spain  How likely are you to reccomend the product?     10
# 1     United States  How likely are you to reccomend the product?      9
# 2            France  How likely are you to reccomend the product?     10
# 3     United States  How likely are you to reccomend the product?     10
# 4            France  How likely are you to reccomend the product?      9
# ...             ...                                           ...    ...
# 1495         Mexico  How likely are you to reccomend the product?      5
# 1496         France  How likely are you to reccomend the product?      5
# 1497  United States  How likely are you to reccomend the product?      3
# 1498  United States  How likely are you to reccomend the product?      0
# 1499  United States  How likely are you to reccomend the product?      0
#
#      nps_bucket
# 0      promoter
# 1      promoter
# 2      promoter
# 3      promoter
# 4      promoter
# ...         ...
# 1495  detractor
# 1496  detractor
# 1497  detractor
# 1498  detractor
# 1499  detractor
#
# [1500 rows x 4 columns]

# %%
#Calculate the overall Score by question
unpivoted = melted_df.groupby(['Country','Question'])['nps_bucket'].apply(lambda x: (x.str.contains('promoter').sum() - x.str.contains('detractor').sum()) / (x.str.contains('promoter').sum() + x.str.contains('passive').sum() + x.str.contains('detractor').sum())).reset_index()
unpivoted_sorted = unpivoted.sort_values(by='nps_bucket', ascending=True)

pivoted = unpivoted.pivot(
    columns='Country',
    index='Question',
    values='nps_bucket')

#pivoted['Percent Change'] = pivoted['Used Messaging'] / pivoted['Did Not Use Messaging'] - 1

#pivoted.reset_index(inplace=True)

# %%
sns.set_style("whitegrid")
sns.set_context("poster", font_scale = 1)
f, ax = plt.subplots(figsize=(20,10))

sns.barplot(data = unpivoted_sorted, 
            x = 'Question', 
            y='nps_bucket', 
            hue='Country',
               ax=ax)
ax.set(xlabel='', ylabel='NPS Score')
ax.yaxis.set_major_formatter(mtick.PercentFormatter(xmax = 1))
ax.legend(loc=9, ncol=5)
ax.set_ylim(.4,.7)
for p in ax.patches:
    ax.annotate("{:.1%}".format(p.get_height()), (p.get_x() + p.get_width() / 2., p.get_height()),ha='center', xytext=(0, 20),textcoords='offset points')
